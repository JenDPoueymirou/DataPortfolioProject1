# %%
import os
import requests
import pandas as pd

# %%
response = requests.get("https://data.cityofnewyork.us/resource/c3uy-2p5r.json?$query=SELECT%20unique_id%2C%20indicator_id%2C%20name%2C%20measure%2C%20measure_info%2C%20geo_type_name%2C%20geo_join_id%2C%20geo_place_name%2C%20time_period%2C%20start_date%2C%20data_value%2C%20message")
response.status_code
# Out:
# 200

# %%
data=response.json()
df=pd.DataFrame(data)
df.to_csv("../data/air_quality_data.csv",index=False)

# %%
print("BOOYEA!")
# Out:
# BOOYEA!
